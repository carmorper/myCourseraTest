# %% [markdown]
# # My Jupyter notebook

# %% [markdown]
# **Carlos**
#
# Mechanical Engineer

# %% [markdown]
# *I am interested in data science because I think it is useful for my job*

# %% [markdown]
# ### My code is going to sum 1 and 2

# %%
1 + 2
# Out:
# 3

# %% [markdown]
# With this code you will learn about:
# * Python
# * Maths
# * Jupyter notebook
#
# But, you will not learn about:
# 1. ~~Java~~
# 2. ~~French language~~
# ![image.png](attachment:image.png)
